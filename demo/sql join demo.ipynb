-- %%
USE f1_presentation

-- %%
SHOW TABLES

-- %%
DESC driverS_standings

-- %%
CREATE OR REPLACE TEMP VIEW v_driver_standings_2018
AS SELECT race_year,driver_name,team,total_points,wins,rank FROM drivers_standings WHERE race_year=2018

-- %%
CREATE OR REPLACE TEMP VIEW v_driver_standings_2020 AS SELECT race_year,driver_name,team, total_points,wins,rank FROM driver_standings WHERE race_year=2020

-- %%
SELECT * FROM v_driver_standings_2018

-- %%
SELECT * FROM v_driver_standings_2020

-- %%
SELECT * FROM v_driver_standings d_2018 JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name

-- %%
SELECT * FROM v_driver_standings d_2018 LEFT JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name

-- %%
SELECT * FROM v_driver_standings d_2018 RIGHT JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name

-- %%
SELECT * FROM v_driver_standings d_2018 FULL JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name

-- %%
SELECT * FROM v_driver_standings d_2018 SEMI JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name

-- %%
SELECT * FROM v_driver_standings d_2018 ANTI JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name

-- %%
SELECT * FROM v_driver_standings d_2018 CROSS JOIN v_driver_standings_2020 d_2020 ON d_2018.driver_name=d_2020.driver_name
