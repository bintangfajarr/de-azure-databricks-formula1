-- %%
SHOW DATABASES

-- %%
SELECT current_database()

-- %%
USE f1_processed

-- %%
SHOW TABLES;

-- %%
SELECT * FROM drivers

-- %%
DESC drivers

-- %%
SELECT * FROM drivers LIMIT 10

-- %%
SELECT * FROM drivers WHERE nationality = 'British'
