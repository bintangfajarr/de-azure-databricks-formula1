# %%
# %run "../includes/configuration"

# %%
race_result_df=spark.read.parquet(f"{presentation_folder_path}/race_results")

# %%
race_result_df.createOrReplaceTempView("v_race_results")

# %%
# %sql
select count(*) from v_race_results
where race_year = 2020

# %%
race_result_2019=spark.sql("select *from v_race_results where race_year=2019")

# %%
p_race_year=2019
race_result_2019=spark.sql(f"select *from v_race_results where race_year={p_race_year}")

# %%
display(race_result_2019)

# %%
race_result_df.createOrReplaceGlobalTempView("gv_race_results")

# %%
# %sql
SHOW TABLES FROM global_temp

# %%
spark.sql("SELECT * FROM global_temp.gv_race_results").show(
    
)
