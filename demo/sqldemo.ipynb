# %%
(%sql
CREATE DATABASE demo;

# %%
# %sql
CREATE DATABASE IF NOT EXISTS demo;

# %%
# %sql
SHOW DATABASES;

# %%
# %sql
DESCRIBE DATABASE demo;

# %%
# %sql
SELECT CURRENT_DATABASE();

# %%
# %sql
SHOW TABLES IN demo;

# %%
# %sql
USE demo

# %%
# %sql
SELECT current_database();

# %%
# %run "../includes/configuration"

# %%
race_results_df=spark.read.parquet(f"{presentation_folder_path}/race_results")

# %%
race_results_df.write.mode("overwrite").saveAsTable("demo.race_results_python")

# %%
# %sql
SHOW TABLES;

# %%
# %sql
SELECT * FROM demo.race_results_python WHERE race_year=2020

# %%
# %sql
CREATE TABLE race_results_sql as SELECT * FROM demo.race_results_python WHERE race_year=2020

# %%
# %sql
SELECT current_database();

# %%
# %sql
DESC EXTENDED demo.race_results_sql

# %%
# %sql
DROP TABLE demo.race_results_sql

# %%
# %sql
SHOW TABLES IN demo

# %%
race_results_df.write.format("parquet").option("path", f"{presentation_folder_path}/race_results_ext_py").saveAsTable("demo.race_results_ext_py")

# %%
# %sql
CREATE TABLE demo.race_results_ext_sql
(
  race_year INT,
  race_name STRING,
  race_date TIMESTAMP,
  circuit_location STRING,
  driver_name STRING,
  driver_number INT,
  driver_nationality STRING,
  team STRING,
  grid INT,
  fastest_lap INT,
  race_time STRING,
  points FLOAT,
  position INT,
  created_date TIMESTAMP
)
USING parquet
LOCATION "dbfs:/FileStore/shared_uploads/race_results_ext_sql"

# %%
# %sql
SHOW TABLES IN demo;

# %%
# %sql
INSERT INTO demo.race_results_ext_sql
SELECT * FROM demo.race_results_ext_py WHERE race_year=2020

# %%
# %sql
SELECT COUNT(1) FROM demo.race_results_ext_sql

# %%
# %sql
SHOW TABLES in demo;

# %%
# %sql
DROP TABLE demo.race_results_ext_sql

# %%
# %sql
SHOW TABLES in demo;
