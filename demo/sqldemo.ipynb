# %%
(%sql
CREATE DATABASE demo;

# %%
# %sql
CREATE DATABASE IF NOT EXISTS demo;

# %%
# %sql
SHOW DATABASES;

# %%
# %sql
DESCRIBE DATABASE demo;

# %%
# %sql
SELECT CURRENT_DATABASE();

# %%
# %sql
SHOW TABLES IN demo;

# %%
# %sql
USE demo

# %%
# %sql
SELECT current_database();
