# %%
raw_folder_path='abfss://raw@formula1dlbtg.dfs.core.windows.net'
processed_folder_path='abfss://processed@formula1dlbtg.dfs.core.windows.net'
presentation_folder_path='abfss://presentation@formula1dlbtg.dfs.core.windows.net'
